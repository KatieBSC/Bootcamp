# %% [markdown]
# ## Evaluation and Visualizations: <br/> Movie (IMDB) Data

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc,roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

# %%
predicts = pd.read_csv("data/movie_pred.csv")
proba = pd.read_csv("data/movie_prob.csv")
predicts = predicts.drop(['Unnamed: 0'], axis = 1)
proba = proba.drop(['Unnamed: 0'], axis = 1)

# %%
predicts.head()
# Out:
#    T_pred  TP_pred  F_pred  True
# 0       1        1       1     0
# 1       1        1       1     1
# 2       1        1       1     1
# 3       1        1       1     0
# 4       1        1       1     1

# %%
proba.head()
# Out:
#      T_prob   TP_prob    F_prob
# 0  0.573366  0.573366  0.519221
# 1  0.573366  0.573366  0.582109
# 2  0.768814  0.768814  0.520411
# 3  0.573366  0.573366  0.531333
# 4  0.573366  0.573366  0.564854

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## ROC Curve

# %%
def ROC_plot (testname, y_true, y_prob):
    
    logit_roc_auc = roc_auc_score(y_true, y_prob)
    
    fpr, tpr, thresholds = roc_curve(y_true, y_prob)
    
    plt.figure()
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([-0.1, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',size=20)
    plt.ylabel('True Positive Rate',size=20)
    plt.xticks(size=15)
    plt.yticks(size=15)
    plt.title('ROC: ' + testname ,size=25)
    
    plt.show()
    print ('ROC_AUC_Score: ' + str(logit_roc_auc))

# %%
ROC_plot('Tree (unpruned)', predicts['True'], proba['T_prob'])
# Out:
# ROC_AUC_Score: 0.7302292256

# %%
ROC_plot('Tree (pruned)', predicts['True'], proba['TP_prob'])
# Out:
# ROC_AUC_Score: 0.7305321344

# %%
ROC_plot('Forest', predicts['True'], proba['F_prob'])
# Out:
# ROC_AUC_Score: 0.7881353152000001
